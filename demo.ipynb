# %%
import pandas as pd

s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Paris', 'London']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London

# %%
data = {
    'Product': ['Pen', 'Pencil', 'Eraser'],
    'Price': [10, 5, 3]
}
df = pd.DataFrame(data)
print(df)
# Out:
#   Product  Price
# 0     Pen     10
# 1  Pencil      5
# 2  Eraser      3

# %%
df = pd.read_csv('hotel_booking.txt',delimiter='\t')  
print(df.head())
# Out:
#          Date Company        Person Name  Room number
# 0  1-Jan-2022  Avamba  Anatole Ridehalgh       4008.0
# 1  1-Jan-2022    Fatz    Aldrich McKevin       2002.0
# 2  1-Jan-2022   Leexo    Stanley Hadrill       4012.0
# 3      Hotels     NaN                NaN          NaN
# 4  1-Jan-2022  Rhyzio       Lyndell Tice       1006.0

# %%
df['Date']
# Out:
# 0      1-Jan-2022
# 1      1-Jan-2022
# 2      1-Jan-2022
# 3          Hotels
# 4      1-Jan-2022
#           ...
# 190     Cleartrip
# 191    1-Jan-2022
# 192    1-Jan-2022
# 193    1-Jan-2022
# 194        Hotels
# Name: Date, Length: 195, dtype: object

# %%
df[['Date', 'Company']]
# Out:
#            Date       Company
# 0    1-Jan-2022        Avamba
# 1    1-Jan-2022          Fatz
# 2    1-Jan-2022         Leexo
# 3        Hotels           NaN
# 4    1-Jan-2022        Rhyzio
# ..          ...           ...
# 190   Cleartrip           NaN
# 191  1-Jan-2022      Fivechat
# 192  1-Jan-2022       Innojam
# 193  1-Jan-2022  Twitterworks
# 194      Hotels           NaN
#
# [195 rows x 2 columns]

# %%
#df.loc[0]     # By label
#df.iloc[0]     # By position
#df.iloc[1:3]   # Slicing rows   
df.iloc[:, 1:3]  # Slicing columns
# Out:
#           Company        Person Name
# 0          Avamba  Anatole Ridehalgh
# 1            Fatz    Aldrich McKevin
# 2           Leexo    Stanley Hadrill
# 3             NaN                NaN
# 4          Rhyzio       Lyndell Tice
# ..            ...                ...
# 190           NaN                NaN
# 191      Fivechat     Corabella Saye
# 192       Innojam  Leandra Potapczuk
# 193  Twitterworks    Valentia Ledson
# 194           NaN                NaN
#
# [195 rows x 2 columns]

# %%
df[(df['Room number'] < 2000) & (df['Company'] == 'Zava')]
# Out:
#           Date Company    Person Name  Room number
# 48  1-Jan-2022    Zava  Ilaire Gaynes       1013.0

# %%
df.isnull().sum()  # Count of null values in each column
# Out:
# Date            0
# Company        61
# Person Name    42
# Room number    42
# dtype: int64

# %%
df.dropna()
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [134 rows x 4 columns]

# %%
df.fillna(0)  # Replace NaN with 0
# Out:
#            Date       Company        Person Name  Room number
# 0    1-Jan-2022        Avamba  Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz    Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo    Stanley Hadrill       4012.0
# 3        Hotels             0                  0          0.0
# 4    1-Jan-2022        Rhyzio       Lyndell Tice       1006.0
# ..          ...           ...                ...          ...
# 190   Cleartrip             0                  0          0.0
# 191  1-Jan-2022      Fivechat     Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam  Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks    Valentia Ledson       1010.0
# 194      Hotels             0                  0          0.0
#
# [195 rows x 4 columns]

# %%
df.groupby('Date').sum() # Group by 'Date' and sum other columns
# Out:
#                                                             Company  \
# Date
# 1-Jan-2022        AvambaFatzLeexoRhyzioEadelOozzInnotypeJayoRiff...
# Booking                                                           0
# Cleartrip                                                         0
# Expedia                                                           0
# Hotels                                                            0
# Travel Agent 007                                                  0
#
#                                                         Person Name  \
# Date
# 1-Jan-2022        Anatole RidehalghAldrich McKevinStanley Hadril...
# Booking                                                           0
# Cleartrip                                                         0
# Expedia                                                           0
# Hotels                                                            0
# ...

# %%
df.dropna()
# Out:
#            Date       Company          Person Name  Room number
# 0    1-Jan-2022        Avamba    Anatole Ridehalgh       4008.0
# 1    1-Jan-2022          Fatz      Aldrich McKevin       2002.0
# 2    1-Jan-2022         Leexo      Stanley Hadrill       4012.0
# 4    1-Jan-2022        Rhyzio         Lyndell Tice       1006.0
# 5    1-Jan-2022         Eadel  Broderic Handscombe       3015.0
# ..          ...           ...                  ...          ...
# 186  1-Jan-2022        Tagpad       Stephani Lafee       1015.0
# 187  1-Jan-2022        Meevee      Victoria Lavery       7002.0
# 191  1-Jan-2022      Fivechat       Corabella Saye       4008.0
# 192  1-Jan-2022       Innojam    Leandra Potapczuk       5002.0
# 193  1-Jan-2022  Twitterworks      Valentia Ledson       1010.0
#
# [134 rows x 4 columns]
